# %% [markdown]
# ref: https://www.ibm.com/communities/analytics/watson-analytics-blog/hr-employee-attrition/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("./IBM_data.csv")
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
f,ax1 = plt.subplots(1,1)
sns.distplot(data['last_evaluation'],bins=10,norm_hist=False)
plt.show()
print('there are {} employees >0.7'.format(len(data[data['last_evaluation']>0.7])))
print('there are {} employees <0.7'.format(len(data[data['last_evaluation']<=0.7])))
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
# /usr/local/lib/python3.5/dist-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
# there are 7802 employees >0.7
# there are 7197 employees <0.7

# %%
corrmat = data.corr()
f, axarr = plt.subplots(2, 2, sharey=True)


sns.heatmap(corrmat, vmax=.8, square=True,ax=axarr[0,0])
axarr[0,0].set_title("For All Employees")
axarr[0,0].xaxis.set_visible(False)

ge = data[data['last_evaluation']>=0.7]
gecorrmat = ge.corr()
axarr[0,1].xaxis.set_visible(False)
axarr[0,1].set_title("last_evaluation > 0.7")
sns.heatmap(gecorrmat, vmax=.8, square=True,ax=axarr[0,1])

be = data[data['last_evaluation']<=0.7]
becorrmat = be.corr()
sns.heatmap(becorrmat, vmax=.8, square=True,ax=axarr[1,0])
axarr[1,0].set_title("last_evaluation <= 0.7")

vbe = data[data['last_evaluation']<=0.5]
vbecorrmat = vbe.corr()
sns.heatmap(vbecorrmat, vmax=.8, square=True,ax=axarr[1,1])
axarr[1,1].set_title("last_evaluation <= 0.5")

plt.show()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
whle_df = data[['last_evaluation','number_project']].copy()
f ,ax1 = plt.subplots(1,1)
ax1.scatter(data['last_evaluation'],data['number_project'])
plt.show()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %% [markdown]
# distribution of employees by department

# %%
vc = data['sales'].value_counts().plot(kind='bar')
plt.show()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %% [markdown]
# proj dist across dept for sales

# %%
var_name = "sales"
col_order = np.sort(data[var_name].unique()).tolist()
plt.figure(figsize=(12,6))
sns.violinplot(x=var_name, y='number_project', data=data, order=col_order)
plt.xlabel(var_name, fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title("Distribution of number_project variable with "+var_name, fontsize=15)
plt.show()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
var_name = "sales"
col_order = np.sort(data[var_name].unique()).tolist()
plt.figure(figsize=(12,6))
sns.violinplot(x=var_name, y='average_montly_hours', data=data, order=col_order)
plt.xlabel(var_name, fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title("average_montly_hours with "+var_name, fontsize=15)
plt.show()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>

# %%
var_name = "salary"
col_order = np.sort(data[var_name].unique()).tolist()
plt.figure(figsize=(12,6))
sns.violinplot(x=var_name, y='satisfaction_level', data=data, order=col_order)
plt.xlabel(var_name, fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title("satisfaction_level with "+var_name, fontsize=15)
plt.show()
# Out:
#           <script src="/static/components/requirejs/require.js"></script>
#           <script>
#             requirejs.config({
#               paths: {
#                 base: '/static/base',
#               },
#             });
#           </script>
